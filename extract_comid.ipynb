# %%
from src.streamcat_fetcher import get_streamcat_data_by_comids

# %%
comid_list = [6097647,6097489] 

stream_data_df = get_streamcat_data_by_comids(comid_list)
stream_data_df
# Out:
# Fetching data for COMID: 6097647...
# Fetching data for COMID: 6097489...
#      comid  regionid  catareasqkm  wsareasqkm  catareasqkmrp100  \
# 0  6097647  Region01       0.0216   1289.4210            0.0162
# 1  6097489  Region01       0.5373   1288.1898            0.1449
#
#    wsareasqkmrp100  catpctfull  wspctfull  pctagslpmid2006cat  \
# 0         229.0428         100        100                0.00
# 1         228.6180         100        100               10.16
#
#    pctagslpmid2006ws  ...  huden2010catrp100  popden2010catrp100  \
# 0                1.6  ...         116.724670           320.45160
# 1                1.6  ...         103.544556           284.18257
#
#    huden2010wsrp100  popden2010wsrp100  huden2010cat  popden2010cat  \
# 0         21.650364          49.779607    110.834905     304.244147
# 1         21.524833          49.417362    107.854083     296.041523
#
#    huden2010ws  popden2010ws  wetindexcat  wetindexws
# ...
